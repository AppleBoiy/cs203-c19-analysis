# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/pongpop/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('../data/data.csv')
df.head()
# Out:
#   Province/State City/County/Borough/Region        Date  Total Death  \
# 0        Alabama                    Choctaw  2022-08-20           37
# 1        Alabama                      Perry  2022-08-20           47
# 2        Alabama                     Wilcox  2022-08-19           48
# 3        Alabama                     Greene  2022-08-19           51
# 4        Alabama                     Sumter  2022-08-20           52
#
#    Total Confirmed  Death Rate
# 0             2155    0.017169
# 1             2366    0.019865
# 2             3299    0.014550
# 3             2079    0.024531
# 4             2882    0.018043

# %%
state_df = df.groupby(df['Province/State']).sum().reset_index()
state_df
# Out:
# /tmp/ipykernel_3113/3775815474.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_df = df.groupby(df['Province/State']).sum().reset_index()
#           Province/State  Total Death  Total Confirmed  Death Rate
# 0                Alabama        20041          1463933    1.102538
# 1                 Alaska         1331           289052    0.111015
# 2                Arizona        30982          2237208    0.261312
# 3               Arkansas        11864           891979    1.242037
# 4             California        94486         10953003    0.469453
# 5               Colorado        13114          1616536    0.768124
# 6            Connecticut        11179           866003    0.100164
# 7               Delaware         3039           299187    0.032853
# 8   District of Columbia         1376           165055    0.008337
# 9                Florida        78049          6976783    1.006101
# 10               Georgia        37934          2722761    3.233126
# 11                Hawaii         1607           327178    0.016910
# 12                 Idaho         5091           485914    0.620466
# 13              Illinois        34598          3644708    1.059246
# 14               Indiana        24245          1873055    1.326933
# 15                  Iowa         9884           832629    1.568520
# 16                Kansas         9009           830781    1.609647
# 17              Kentucky        16541          1504161    1.610179
# 18             Louisiana        17783          1407562    0.931642
# 19                 Maine         2500           280138    0.149092
# 20              Maryland        15315          1209312    0.364443
# 21         Massachusetts        21338          1828344    0.149819
# 22              Michigan        37737          2722698    1.389545
# 23             Minnesota        13044          1620424    0.835051
# 24           Mississippi        12729           894772    1.365573
# 25              Missouri        21310          1602739    1.981132
# 26               Montana         3493           302291    0.927318
# 27              Nebraska         3554           502019    1.148662
# 28                Nevada        11353           829615    0.347069
# 29         New Hampshire         2641           340023    0.080672
# 30            New Jersey        34793          2625460    0.291108
# 31            New Mexico         8347           598502    0.604571
# 32              New York        70350          5937090    0.606190
# 33        North Carolina        25769          3071630    1.062725
# 34          North Dakota         2233           260871    0.668121
# 35                  Ohio        39305          3026110    1.336863
# 36              Oklahoma        14646          1149810    1.173774
# 37                Oregon         8342           870688    0.447493
# 38          Pennsylvania        46514          3150248    1.156904
# 39           Puerto Rico         1787           726217    0.448959
# 40          Rhode Island         3632           386380    0.040992
# 41        South Carolina        18231          1644297    0.627873
# 42          South Dakota         2981           254086    1.129625
# 43             Tennessee        26692          2144867    1.431431
# 44                 Texas        89964          7667884    5.011501
# 45                  Utah         4947          1019966    0.089494
# 46               Vermont          698           137195    0.066789
# 47              Virginia        21284          2009271    1.918278
# 48            Washington        13919          1766550    0.410905
# 49         West Virginia         7239           571829    0.729915
# 50             Wisconsin        15010          1814141    0.723356
# 51               Wyoming         1872           173296    0.287023

# %%
state_df.drop(columns=['Total Confirmed', 'Death Rate'], inplace=True)
state_df.head()
# Out:
#   Province/State  Total Death
# 0        Alabama        20041
# 1         Alaska         1331
# 2        Arizona        30982
# 3       Arkansas        11864
# 4     California        94486

# %%
state_df = state_df.sort_values(by='Total Death', ascending=False)
state_df
# Out:
#    Province/State  Total Death
# 4      California        94486
# 44          Texas        89964
# 9         Florida        78049
# 32       New York        70350
# 38   Pennsylvania        46514

# %%
state_df = state_df[:5]
plt.figure(figsize=(10, 7))
plt.bar(state_df['Province/State'], state_df['Total Death'], width = 0.4, color='orange')
plt.xlabel('Province/State')
plt.ylabel('Total Death')
plt.title('Total Deaths by Province/State')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
