# %%
import src.plotter as plotter
import pandas as pd
from IPython.display import Image

# %%
df = pd.read_csv('../data/data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3232 entries, 0 to 3231
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Province/State              3232 non-null   object
#  1   City/County/Borough/Region  3232 non-null   object
#  2   Date                        3232 non-null   object
#  3   Total Death                 3232 non-null   int64
#  4   Total Confirmed             3232 non-null   int64
#  5   Death Rate                  3232 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 151.6+ KB

# %%
df['Death Rate'].describe()
# Out:
# count    3232.000000
# mean        0.014258
# std         0.007623
# min         0.000000
# 25%         0.009905
# 50%         0.013487
# 75%         0.017687
# max         0.108322
# Name: Death Rate, dtype: float64

# %%
plotter.histogram_plot(
    df['Death Rate'],
    'Death Rate',
    bins=20,
    path='../images/death_rate_hist.png',
)

Image('../images/death_rate_hist.png')

# %%
plotter.box_plot(
    df['Death Rate'],
    'Death Rate',
    path='../images/death_rate_box.png',
)

Image('../images/death_rate_box.png')

# %%
plotter.density_plot(
    df['Death Rate'],
    'Death Rate',
    path='../images/death_rate_density.png',
)

Image('../images/death_rate_density.png')
