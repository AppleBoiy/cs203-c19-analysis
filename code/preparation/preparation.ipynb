# %%
import pandas as pd
# Out:
# /home/kws654/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
def get_data():
    data = pd.read_csv('../../data/coronavirus-covid-19-pandemic-usa-counties.csv')
    return data

# %%
df = get_data()

# %%
df.head()
# Out:
#                                                     Admin 2 FIPS Code;Province/State;Admin 2 Level (City/County/Borough/Region);Date;Total Death;Total Confirmed;location
# 12119;Florida;Sumter;2020-01-31;0;0;28.70181754                                            -82.079427
# 13153;Georgia;Houston;2020-01-31;0;0;32.45802497                                           -83.668791
# 13227;Georgia;Pickens;2020-01-31;0;0;34.46589159                                           -84.464066
# 13303;Georgia;Washington;2020-01-31;0;0;32.9671...                                         -82.793570
# 16003;Idaho;Adams;2020-01-31;0;0;44.89333571                                              -116.454525

# %%
dt = pd.read_csv('../../data/coronavirus-covid-19-pandemic-usa-counties.csv', sep=';')

# %%
dt.head()
# Out:
#    Admin 2 FIPS Code Province/State  \
# 0            12119.0        Florida
# 1            13153.0        Georgia
# 2            13227.0        Georgia
# 3            13303.0        Georgia
# 4            16003.0          Idaho
#
#   Admin 2 Level (City/County/Borough/Region)        Date  Total Death  \
# 0                                     Sumter  2020-01-31            0
# 1                                    Houston  2020-01-31            0
# 2                                    Pickens  2020-01-31            0
# 3                                 Washington  2020-01-31            0
# 4                                      Adams  2020-01-31            0
#
#    Total Confirmed                  location
# 0                0   28.70181754,-82.0794267
# 1                0  32.45802497,-83.66879087
# 2                0  34.46589159,-84.46406611
# 3                0  32.96711864,-82.79357039
# 4                0  44.89333571,-116.4545247

# %%
state_name_of_us = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

dt['CODE'] = dt['Province/State'].map(state_name_of_us)
dt.head()
# Out:
#    Admin 2 FIPS Code Province/State  \
# 0            12119.0        Florida
# 1            13153.0        Georgia
# 2            13227.0        Georgia
# 3            13303.0        Georgia
# 4            16003.0          Idaho
#
#   Admin 2 Level (City/County/Borough/Region)        Date  Total Death  \
# 0                                     Sumter  2020-01-31            0
# 1                                    Houston  2020-01-31            0
# 2                                    Pickens  2020-01-31            0
# 3                                 Washington  2020-01-31            0
# 4                                      Adams  2020-01-31            0
#
#    Total Confirmed                  location CODE
# 0                0   28.70181754,-82.0794267   FL
# 1                0  32.45802497,-83.66879087   GA
# 2                0  34.46589159,-84.46406611   GA
# 3                0  32.96711864,-82.79357039   GA
# 4                0  44.89333571,-116.4545247   ID

# %%
dt['Admin 2 FIPS Code'].duplicated() #check duplicate
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3099175     True
# 3099176     True
# 3099177     True
# 3099178     True
# 3099179     True
# Name: Admin 2 FIPS Code, Length: 3099180, dtype: bool

# %%
dt['Province/State'].unique() #check unique
# Out:
# array(['Florida', 'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa',
#        'Kansas', 'Kentucky', 'Louisiana', 'Maryland', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Puerto Rico', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Virginia', 'West Virginia', 'Wisconsin',
#        'Alabama', 'Alaska', 'Arkansas', 'California', 'Colorado', 'Maine',
#        'Northern Mariana Islands', 'Vermont', 'Washington', 'Wyoming',
#        'Arizona', 'Massachusetts', 'New Hampshire', 'Rhode Island',
#        'Connecticut', 'Grand Princess', 'Hawaii', 'Delaware', 'Nevada',
#        'Guam', 'District of Columbia', 'Diamond Princess',
#        'American Samoa', 'Virgin Islands'], dtype=object)

# %%
dt['Province/State'].nunique() #check number of unique
# Out:
# 58

# %%
dt.isna().any() #check empty
# Out:
# Admin 2 FIPS Code                              True
# Province/State                                False
# Admin 2 Level (City/County/Borough/Region)     True
# Date                                          False
# Total Death                                   False
# Total Confirmed                               False
# location                                      False
# CODE                                           True
# dtype: bool

# %%
dt[['lat', 'lon']] = dt['location'].str.split(',', expand=True)
dt.drop(columns=['location'], inplace=True)
dt.head()
# Out:
#    Admin 2 FIPS Code Province/State  \
# 0            12119.0        Florida
# 1            13153.0        Georgia
# 2            13227.0        Georgia
# 3            13303.0        Georgia
# 4            16003.0          Idaho
#
#   Admin 2 Level (City/County/Borough/Region)        Date  Total Death  \
# 0                                     Sumter  2020-01-31            0
# 1                                    Houston  2020-01-31            0
# 2                                    Pickens  2020-01-31            0
# 3                                 Washington  2020-01-31            0
# 4                                      Adams  2020-01-31            0
#
#    Total Confirmed CODE          lat           lon
# 0                0   FL  28.70181754   -82.0794267
# 1                0   GA  32.45802497  -83.66879087
# 2                0   GA  34.46589159  -84.46406611
# 3                0   GA  32.96711864  -82.79357039
# 4                0   ID  44.89333571  -116.4545247

# %%
check_zero_location = dt[(dt['lat'] == '0.0') | (dt['lon'] == '0.0')]
check_zero_location.head()
# Out:
#      Admin 2 FIPS Code Province/State  \
# 30                 NaN       Michigan
# 35             80027.0      Minnesota
# 44             80035.0     New Mexico
# 104            80008.0       Colorado
# 164            80035.0     New Mexico
#
#     Admin 2 Level (City/County/Borough/Region)        Date  Total Death  \
# 30   Michigan Department of Corrections (MDOC)  2020-01-31            0
# 35                                   Out of MN  2020-01-31            0
# 44                                   Out of NM  2020-01-31            0
# 104                                  Out of CO  2020-02-01            0
# 164                                  Out of NM  2020-02-01            0
#
#      Total Confirmed CODE  lat  lon
# 30                 0   MI  0.0  0.0
# 35                 0   MN  0.0  0.0
# 44                 0   NM  0.0  0.0
# 104                0   CO  0.0  0.0
# 164                0   NM  0.0  0.0

# %%
dt.dropna() #delete empty rows
# Out:
#          Admin 2 FIPS Code Province/State  \
# 0                  12119.0        Florida
# 1                  13153.0        Georgia
# 2                  13227.0        Georgia
# 3                  13303.0        Georgia
# 4                  16003.0          Idaho
# ...                    ...            ...
# 3099175             5083.0       Arkansas
# 3099176             6009.0     California
# 3099177             6035.0     California
# 3099178             6037.0     California
# 3099179            12005.0        Florida
#
#         Admin 2 Level (City/County/Borough/Region)        Date  Total Death  \
# 0                                           Sumter  2020-01-31            0
# 1                                          Houston  2020-01-31            0
# 2                                          Pickens  2020-01-31            0
# 3                                       Washington  2020-01-31            0
# ...

# %%
dt['Province/State'].nunique()
# Out:
# 58

# %%
dt = dt.dropna(subset=['CODE'])

# %%
dt['Province/State'].nunique()
# Out:
# 50

# %%
dt.isna().sum()
# Out:
# Admin 2 FIPS Code                             9420
# Province/State                                   0
# Admin 2 Level (City/County/Borough/Region)       0
# Date                                             0
# Total Death                                      0
# Total Confirmed                                  0
# CODE                                             0
# lat                                              0
# lon                                              0
# dtype: int64
